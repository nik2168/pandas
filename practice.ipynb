# %%
import pandas as pd

df = pd.DataFrame([[1, 2, 3], [4, 5, 6], [7, 8, 9]], columns=["A", "B", "C"], index=["x", "y", "z"])

df.info() # print info
df.head() # print n first rows
df.tail(2) # print n last rows
df.describe() # print summary statistics
df.shape # dataframe dimensions r * c
df['A'].unique() # unique values in col A
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, x to z
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      int64
#  1   B       3 non-null      int64
#  2   C       3 non-null      int64
# dtypes: int64(3)
# memory usage: 96.0+ bytes
# array([1, 4, 7])

# %% [markdown]
# ### Loading Data From Files

# %%
coffee =  pd.read_csv('./warmup-data/coffee.csv')
results = pd.read_parquet('./data/results.parquet')
bios = pd.read_csv('./data/bios.csv')
# bios.head(3)
coffee.tail(3)
# Out:
#          Day Coffee Type  Units Sold
# 11  Saturday       Latte          35
# 12    Sunday    Espresso          45
# 13    Sunday       Latte          35

# %% [markdown]
# ## Accessing Data In Pandas

# %%
coffee.head() # only first 5
coffee # full data frame
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee.loc[[0, 1, 2]] # print first three rows ...
coffee.loc[:4] # numpy like syntax 

coffee.loc[:3, ["Day", "Units Sold"]] # print first three rows of Day and Units Sold
coffee.iloc[:3, [0, 2]] # use index instead of names
coffee.iat[1, 2] # grab only single value - more optimized for single only
# Out:
# np.int64(15)

# %%
# coffee.index = coffee["Day"] # remove the index bold
# coffee.loc["Monday":"Wednesday"] # prints data on based of string name filters

# %% [markdown]
# # Update Values of data frame

# %%
coffee.loc[1, "Units Sold"] = 13
coffee.loc[1]

coffee.sort_values(["Units Sold"], ascending=[False])

for index, row in coffee.iterrows():
    print(index)
    print(row["Coffee Type"])
    print("Coffee Type of Row:", row["Coffee Type"])
    print("\n \n \n")
# Out:
# 0
# Espresso
# Coffee Type of Row: Espresso
#
#
#
#
# 1
# Latte
# Coffee Type of Row: Latte
#
#
#
#
# 2
# Espresso
# Coffee Type of Row: Espresso
#
#
#
#
# 3
# Latte
# Coffee Type of Row: Latte
#
#
#
#
# 4
# Espresso
# Coffee Type of Row: Espresso
#
#
#
#
# 5
# Latte
# Coffee Type of Row: Latte
#
#
#
#
# 6
# Espresso
# Coffee Type of Row: Espresso
#
#
#
#
# 7
# Latte
# Coffee Type of Row: Latte
#
#
#
#
# 8
# Espresso
# Coffee Type of Row: Espresso
#
#
#
#
# 9
# Latte
# Coffee Type of Row: Latte
#
#
#
#
# 10
# Espresso
# Coffee Type of Row: Espresso
#
#
#
#
# 11
# Latte
# Coffee Type of Row: Latte
#
#
#
#
# 12
# Espresso
# Coffee Type of Row: Espresso
#
#
#
#
# 13
# Latte
# Coffee Type of Row: Latte

# %%
bios.loc[bios["height_cm"] > 215]
# Out:
#         athlete_id                   name   born_date               born_city  \
# 5089          5108     Viktor Pankrashkin  1957-06-19         Moskva (Moscow)
# 5583          5606   Paulinho Villas Boas  1963-01-26               São Paulo
# 5673          5696         Gunther Behnke  1963-01-19              Leverkusen
# 5716          5739               Uwe Blab  1962-03-26        München (Munich)
# 5781          5804         Tommy Burleson  1952-02-24               Crossnore
# 5796          5819          Andy Campbell  1956-07-21               Melbourne
# 6223          6250            Lars Hansen  1954-09-27  København (Copenhagen)
# 6270          6298            Hu Zhangbao  1963-04-05                     NaN
# 6409          6440       Sergey Kovalenko  1947-08-11                     NaN
# 6420          6451          Jānis Krūmiņš  1930-01-30                   Cēsis
# 6504          6537            Luc Longley  1969-01-19               Melbourne
# ...

# %%
bios[bios['height_cm'] > 220][["name","height_cm"]] # prints data on based of string name filters
bios[(bios['height_cm'] > 220) & (bios['born_country']=='USA')][["name", 'born_country', "height_cm"]]  # multiple conditions
bios[bios["born_country"].isin(["USA", "FRA", "GBR"]) & (bios["name"].str.startswith("Keith"))]

bios.query('height_cm > 220 and born_country == "USA"')  # simply filter with python queries
# Out:
#       athlete_id            name   born_date  born_city     born_region  \
# 5781        5804  Tommy Burleson  1952-02-24  Crossnore  North Carolina
#
#      born_country            NOC  height_cm  weight_kg died_date
# 5781          USA  United States      223.0      102.0       NaN

# %%
coffee["price"] = 4.99
coffee.head()
# Out:
#          Day Coffee Type  Units Sold  price
# 0     Monday    Espresso          25   4.99
# 1     Monday       Latte          13   4.99
# 2    Tuesday    Espresso          30   4.99
# 3    Tuesday       Latte          20   4.99
# 4  Wednesday    Espresso          35   4.99

# %% [markdown]
# Now, if we want to update price for Latte using conditions of Numpy then

# %%
import numpy as np

coffee['new_price'] = np.where(coffee['Coffee Type']=='Espresso', 3.99, 5.99)
coffee.drop(columns=['price'], inplace=True) # modify the coffee in place instead of creating a new df
coffee.head()

coffee_new = coffee.copy() # create a new df, if not using copy then it will point to the same df insted of a copy
# Out:
#          Day Coffee Type  Units Sold  new_price
# 0     Monday    Espresso          25       3.99
# 1     Monday       Latte          13       5.99
# 2    Tuesday    Espresso          30       3.99
# 3    Tuesday       Latte          20       5.99
# 4  Wednesday    Espresso          35       3.99
